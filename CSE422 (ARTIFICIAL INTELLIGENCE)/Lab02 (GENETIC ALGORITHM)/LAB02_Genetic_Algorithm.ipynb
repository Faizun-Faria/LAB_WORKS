# %% [markdown]
# ## CSE422 lab: Genetic Algorithm

# %% [markdown]
# #### Genetic Algorithm Pseudo code:

# %% [markdown]
# **function** GENETIC-ALGORITHM( population, FITNESS-FN) **returns** an individual
#
# > **inputs:** population- a set of individuals/chromosomes; FITNESS-FN- a function that measures the fitness of an individual
#
# >**repeat**
# new_population $\leftarrow$ empty set
# >>**for** $i=1$ **to** size ($ population$) **do**
# $$
# \begin{array}{l}
# x \leftarrow \text { RANDOM-SELECTION }(\text { population, FITNESS-FN }) \\
# y \leftarrow \text { RANDOM-SELECTION }(\text { population, FITNESS-FN }) \\
# child  \leftarrow \operatorname{CROSSOVER}(x, y)
# \end{array}
# $$
# >>>**if** (some_random_number < mutation_threshold) **then** child$\leftarrow$ MUTATE ( child )
#
# >>>add child to new_population
#
# >>population $\leftarrow$ new_population
#
# >**until** some individual is fit enough, or enough time has elapsed
#
# >**return** the best individual in population, according to FITNESS-FN

# %% [markdown]
# ###Importing Libraries

# %%
import numpy as np
import random
global min_fit_ind
global max_fitness_found
min_fit_ind = 0

# %% [markdown]
# ### Fitness function

# %%
def fitness(population, n):

  '''calculates the fitness score of each
     of the individuals in the population
     
     returns a 1D numpy array: index referring to 
     ith individual in population, and value referring 
     to the fitness score.'''
  non_attacking_pair = {}
  for i in range(0,n):
    row = population[i]
    ans = 0
    #
    for j in range(0,n-1):
      for k in range(j+1,n):
        if row[k]==row[j]:
          ans += 1
      X = j
      Y = row[j]
      count = 1
      y= Y
      #Diagonally attacking pairs
      while (y+count)<n and X+count<n:
        if row[X+count] == y+count:
          ans += 1
        count += 1
      count = 1
      y= Y
      while (y-count)>=0 and X+count<n:
        if row[X+count] == y-count:
          ans += 1
        count += 1
    # Horizontally, Vertically and Diagonally non-attacking pairs 
    non_attacking_pair[i]=int(n*(n-1)/2 - ans)  
  fit = {}
  for i in range(0,n):
    fit[i]= non_attacking_pair[i]
  return fit

# %% [markdown]
# ### Random Selection function
#
# This built-in function might help to create the weighted random selection:
#
# `numpy.random.choice(a, size, replace, p)`
#
# `p` are the weights of the individuals- value between 0 and 1; refers to the probability of each individual being selected.
#
# `a` is the array
#
# `size` how many samples to return
#
# `replace = True`

# %%
def select(population, fit):
  ''' take input:  population and fit
      fit contains fitness values of each of the individuals 
      in the population  
      
      return:  one individual randomly giving
      more weight to ones which have high fitness score'''
  r = random.randint(0,n-2)  
  while r==min_fit_ind or (r+1)==min_fit_ind or visited[r]==1:
    r = random.randint(0,n-2)  
  visited[r]=1
  return r

# %% [markdown]
# ### Crossover function
#
#
# **function** CROSSOVER $(x, y)$ **returns** an individual
#
# >**inputs**: $x, y$  which are the parent individuals
#
# >$n \leftarrow \mathrm{LENGTH}(x) ; c \leftarrow$ random number from 1 to $n$
#
# >**return** APPEND(SUBSTRING $(x, 1, c),$ SUBSTRING $(y, c+1, n))$

# %%
def crossover(x, y):
  '''take input: 2 parents - x, y. 
     Generate a random crossover point. 
     Append first half of x with second 
     half of y to create the child
     
     returns: a child chromosome'''
  children = {}
  l = len(x)
  r = random.randint(0, l)
  child1 = np.concatenate((x[0:r],y[r:l]),axis=0)
  child2 = np.concatenate((y[0:r],x[r:l]),axis=0)
  children[0] = child1
  children[1] = child2   
  return children

# %% [markdown]
# ###Mutation function

# %%
def mutate(child):
  '''take input: a child
     mutates a random 
     gene into another random gene
     
     returns: mutated child'''
  l = len(child)
  r_ind = random.randint(0,l-1)
  r_val = random.randint(0,l-1)
  child[r_ind] = r_val
  return child

# %% [markdown]
# ###Print Chromosome and Fitness

# %%
def printAll(population, fit):
  for i in range(0,len(fit)):
    print("Chromosome:"+str(population[i])+"  "+"Fitness:"+str(fit[i]))
    m = int(len(fit)*(len(fit)-1)/2)
    if fit[i]>=m:
      global max_fitness_found
      max_fitness_found = True
      break
  print()

# %% [markdown]
# ### Genetic Algorithm Function

# %%
def GA(population, n, mutation_threshold = 0.3):
  '''implement the pseudocode here by
     calling the necessary functions- Fitness, 
     Selection, Crossover and Mutation
     
     print: the max fitness value and the 
     chromosome that generated it which is ultimately 
     the solution board'''
  fit = fitness(population, n)
  min_fit = fit[0] 
  min_fit_ind = 0
  for i in range(0,n):
    if fit[i]<min_fit:
      min_fit_ind = i 
      min_fit = fit[i]  
  printAll(population, fit)
  new_population = {} 
  count = 0    
  for i in range(0,int(n/2)):
    ind = select(population, fit)
    children = crossover(population[ind], population[ind+1])
    new_population[count]=children[0] 
    new_population[count+1]=children[1] 
    r = random.random()
    if r*0.01 < mutation_threshold:
      new_population[count] = mutate(new_population[count])
    r = random.random()
    if r*0.01 < mutation_threshold:
      new_population[count+1] = mutate(new_population[count+1])  
    count += 2
  return new_population

# %% [markdown]
# ###Running the Genetic Algorithm function

# %%
'''for 8 queen problem, n = 8'''
n = 8

'''start_population denotes how many individuals/chromosomes are there
  in the initial population n = 8'''
start_population = 8 

'''if you want you can set mutation_threshold to a higher value,
   to increase the chances of mutation'''
mutation_threshold = 0.3

'''creating the population with random integers between 0 to 7 inclusive
   for n = 8 queen problem'''
population = np.random.randint(0, n, (start_population, n))
'''calling the GA function'''
i = 0
max_fitness_found = False
while i<100 and max_fitness_found==False:
  visited = np.zeros(n)
  population = GA(population, n, mutation_threshold)
  i+=1
# Out:
# Chromosome:[0 5 2 0 3 6 5 2]  Fitness:22
# Chromosome:[6 1 4 1 3 2 6 4]  Fitness:21
# Chromosome:[1 5 1 2 7 4 4 4]  Fitness:20
# Chromosome:[1 4 5 5 0 3 4 1]  Fitness:20
# Chromosome:[4 1 5 5 0 0 3 7]  Fitness:24
# Chromosome:[2 7 2 6 3 1 5 1]  Fitness:24
# Chromosome:[3 2 1 3 2 1 5 7]  Fitness:17
# Chromosome:[2 7 7 4 6 3 3 1]  Fitness:21
#
# Chromosome:[0 7 2 6 3 1 5 1]  Fitness:24
# Chromosome:[4 1 5 5 0 0 3 1]  Fitness:23
# Chromosome:[3 4 7 4 6 3 3 1]  Fitness:21
# Chromosome:[2 7 1 3 2 4 5 7]  Fitness:21
# Chromosome:[4 1 5 5 7 0 3 7]  Fitness:24
# Chromosome:[1 4 5 3 0 3 4 1]  Fitness:22
# Chromosome:[1 4 5 5 0 6 4 1]  Fitness:22
# Chromosome:[1 5 1 2 7 4 4 4]  Fitness:20
#
# Chromosome:[1 5 5 5 0 6 4 1]  Fitness:22
# Chromosome:[1 5 7 2 7 4 4 4]  Fitness:21
# Chromosome:[3 4 7 4 2 4 5 7]  Fitness:21
# Chromosome:[2 7 1 7 6 3 3 1]  Fitness:20
# Chromosome:[4 1 5 3 0 0 3 1]  Fitness:23
# Chromosome:[3 4 7 4 6 7 3 1]  Fitness:22
# Chromosome:[1 5 5 3 0 3 4 1]  Fitness:22
# Chromosome:[1 7 5 5 0 6 4 1]  Fitness:22
#
# Chromosome:[1 5 5 3 0 3 4 1]  Fitness:22
# Chromosome:[1 7 5 5 0 6 4 1]  Fitness:22
# Chromosome:[4 4 7 4 6 7 4 1]  Fitness:19
# Chromosome:[1 5 5 3 0 3 2 1]  Fitness:20
# Chromosome:[1 4 7 4 2 4 5 7]  Fitness:21
# Chromosome:[2 7 1 7 1 3 3 1]  Fitness:19
# Chromosome:[2 7 1 7 0 7 3 1]  Fitness:22
# Chromosome:[4 4 5 3 6 3 3 1]  Fitness:22
#
# Chromosome:[7 5 5 3 0 3 2 1]  Fitness:20
# Chromosome:[7 4 7 4 6 7 4 1]  Fitness:19
# Chromosome:[1 0 7 4 2 4 5 7]  Fitness:20
# Chromosome:[1 6 5 3 0 3 2 1]  Fitness:21
# Chromosome:[2 7 1 7 1 7 3 1]  Fitness:19
# Chromosome:[2 5 1 7 0 3 3 1]  Fitness:24
# Chromosome:[1 7 5 4 6 7 4 1]  Fitness:20
# Chromosome:[4 4 7 5 0 6 4 6]  Fitness:23
#
# Chromosome:[1 7 5 4 6 7 4 1]  Fitness:20
# Chromosome:[4 4 7 5 0 6 4 6]  Fitness:23
# Chromosome:[2 7 5 4 6 7 4 1]  Fitness:20
# Chromosome:[3 5 1 7 0 3 3 1]  Fitness:21
# Chromosome:[1 7 5 3 0 3 2 1]  Fitness:19
# Chromosome:[2 7 1 7 1 7 3 1]  Fitness:19
# Chromosome:[5 6 5 3 0 3 2 1]  Fitness:20
# Chromosome:[4 0 7 4 2 4 5 7]  Fitness:20
#
# Chromosome:[3 5 1 3 0 3 2 1]  Fitness:18
# Chromosome:[1 7 6 7 0 3 3 1]  Fitness:18
# Chromosome:[4 4 7 7 0 6 4 1]  Fitness:21
# Chromosome:[2 7 5 4 6 1 4 6]  Fitness:23
# Chromosome:[1 7 5 3 1 4 3 1]  Fitness:21
# Chromosome:[5 7 1 7 0 3 2 1]  Fitness:19
# Chromosome:[5 0 2 4 2 4 5 7]  Fitness:21
# Chromosome:[4 6 5 3 0 3 2 0]  Fitness:20
#
# Chromosome:[2 7 5 3 1 4 3 2]  Fitness:22
# Chromosome:[1 7 4 4 6 1 4 6]  Fitness:19
# Chromosome:[2 7 5 4 6 5 4 6]  Fitness:20
# Chromosome:[5 4 7 7 0 6 4 1]  Fitness:23
# Chromosome:[5 0 3 4 2 4 5 0]  Fitness:19
# Chromosome:[4 6 3 3 0 3 2 7]  Fitness:21
# Chromosome:[1 7 6 7 0 6 4 1]  Fitness:19
# Chromosome:[4 4 7 7 0 3 3 3]  Fitness:18
#
# Chromosome:[5 0 3 3 0 6 2 7]  Fitness:22
# Chromosome:[4 3 3 4 2 4 5 0]  Fitness:20
# Chromosome:[1 7 6 7 0 6 4 3]  Fitness:19
# Chromosome:[4 1 7 7 0 3 3 1]  Fitness:21
# Chromosome:[5 4 7 4 2 4 2 0]  Fitness:20
# Chromosome:[5 0 3 7 0 0 4 1]  Fitness:21
# Chromosome:[2 7 7 3 0 6 4 1]  Fitness:26
# Chromosome:[5 4 5 4 5 5 4 6]  Fitness:14
#
# Chromosome:[5 4 7 4 1 0 4 1]  Fitness:17
# Chromosome:[5 0 3 4 2 4 2 0]  Fitness:21
# Chromosome:[5 7 7 3 0 5 4 6]  Fitness:23
# Chromosome:[5 4 5 4 5 6 7 1]  Fitness:15
# Chromosome:[2 7 7 3 0 6 4 1]  Fitness:26
# Chromosome:[5 0 3 7 0 0 2 1]  Fitness:20
# Chromosome:[4 3 3 4 2 3 4 3]  Fitness:13
# Chromosome:[1 7 6 7 3 6 5 0]  Fitness:20
#
# Chromosome:[5 4 5 4 0 6 0 1]  Fitness:20
# Chromosome:[2 7 7 3 2 6 7 1]  Fitness:21
# Chromosome:[5 7 7 1 0 5 4 1]  Fitness:20
# Chromosome:[5 4 5 4 5 6 7 2]  Fitness:14
# Chromosome:[5 0 5 3 0 5 4 6]  Fitness:21
# Chromosome:[5 7 3 4 2 4 2 0]  Fitness:22
# Chromosome:[2 7 3 1 0 0 2 1]  Fitness:19
# Chromosome:[5 0 7 3 0 6 3 1]  Fitness:24
#
# Chromosome:[5 7 7 1 0 5 4 1]  Fitness:20
# Chromosome:[2 7 7 3 2 6 4 1]  Fitness:23
# Chromosome:[2 7 3 1 0 0 2 1]  Fitness:19
# Chromosome:[5 7 3 4 1 4 2 0]  Fitness:21
# Chromosome:[5 7 7 1 0 5 4 3]  Fitness:19
# Chromosome:[5 4 5 2 5 6 7 1]  Fitness:18
# Chromosome:[4 7 3 4 2 4 2 0]  Fitness:21
# Chromosome:[5 0 7 3 0 5 4 6]  Fitness:22
#
# Chromosome:[4 7 3 1 0 5 4 3]  Fitness:18
# Chromosome:[5 7 7 6 1 4 2 0]  Fitness:21
# Chromosome:[4 7 3 4 2 4 3 0]  Fitness:21
# Chromosome:[5 0 7 3 2 5 4 6]  Fitness:21
# Chromosome:[3 4 5 2 5 6 7 1]  Fitness:20
# Chromosome:[5 7 7 1 6 5 4 3]  Fitness:18
# Chromosome:[5 4 5 2 5 6 7 6]  Fitness:15
# Chromosome:[4 7 3 3 2 4 2 0]  Fitness:23
#
# Chromosome:[5 7 7 1 0 5 4 3]  Fitness:19
# Chromosome:[3 4 5 5 5 6 7 1]  Fitness:18
# Chromosome:[4 7 3 7 2 4 3 0]  Fitness:23
# Chromosome:[7 7 7 6 1 4 2 0]  Fitness:20
# Chromosome:[5 7 7 1 6 6 7 5]  Fitness:20
# Chromosome:[5 4 5 2 5 5 3 3]  Fitness:15
# Chromosome:[5 7 3 3 4 4 2 0]  Fitness:21
# Chromosome:[4 4 5 2 5 6 7 1]  Fitness:21
#
# Chromosome:[5 7 5 2 5 6 7 1]  Fitness:19
# Chromosome:[4 4 3 3 3 4 2 0]  Fitness:19
# Chromosome:[5 7 3 5 4 4 2 0]  Fitness:19
# Chromosome:[5 4 5 2 5 5 3 6]  Fitness:16
# Chromosome:[7 5 7 6 1 6 7 5]  Fitness:21
# Chromosome:[5 7 7 1 6 4 2 0]  Fitness:24
# Chromosome:[7 0 7 6 1 4 2 0]  Fitness:21
# Chromosome:[4 6 3 7 2 4 3 0]  Fitness:23
#
# Chromosome:[5 7 7 6 1 1 2 0]  Fitness:21
# Chromosome:[7 0 7 1 6 4 2 6]  Fitness:22
# Chromosome:[7 0 7 6 1 4 4 0]  Fitness:20
# Chromosome:[4 6 3 7 2 4 0 0]  Fitness:23
# Chromosome:[5 7 3 5 4 4 3 6]  Fitness:19
# Chromosome:[5 4 5 2 5 5 6 0]  Fitness:16
# Chromosome:[5 4 5 2 1 6 1 5]  Fitness:16
# Chromosome:[7 5 7 6 5 5 3 1]  Fitness:18
#
# Chromosome:[4 6 3 7 4 4 6 6]  Fitness:19
# Chromosome:[5 7 3 5 3 4 0 0]  Fitness:21
# Chromosome:[7 0 7 7 2 4 0 0]  Fitness:18
# Chromosome:[4 6 3 6 1 4 4 2]  Fitness:20
# Chromosome:[5 4 5 2 3 5 6 0]  Fitness:16
# Chromosome:[5 7 3 5 4 4 0 6]  Fitness:21
# Chromosome:[5 4 5 1 5 5 3 1]  Fitness:18
# Chromosome:[7 5 7 6 1 6 2 5]  Fitness:24
#
# Chromosome:[4 6 6 6 1 4 4 2]  Fitness:18
# Chromosome:[5 4 5 2 3 1 6 0]  Fitness:19
# Chromosome:[7 0 7 6 1 4 4 1]  Fitness:21
# Chromosome:[7 6 3 7 2 4 0 0]  Fitness:22
# Chromosome:[5 4 5 1 5 5 7 5]  Fitness:14
# Chromosome:[7 5 7 6 1 6 3 7]  Fitness:20
# Chromosome:[5 0 7 7 2 4 2 0]  Fitness:22
# Chromosome:[7 7 3 5 3 1 0 0]  Fitness:20
#
# Chromosome:[6 4 5 1 5 5 7 5]  Fitness:19
# Chromosome:[7 6 3 5 2 4 0 0]  Fitness:23
# Chromosome:[5 4 5 1 5 5 3 0]  Fitness:18
# Chromosome:[7 5 7 6 1 6 7 5]  Fitness:21
# Chromosome:[7 5 7 4 1 6 3 0]  Fitness:21
# Chromosome:[5 4 7 7 2 4 2 7]  Fitness:20
# Chromosome:[7 0 4 7 2 4 0 0]  Fitness:18
# Chromosome:[7 6 3 6 1 4 6 1]  Fitness:21
#
# Chromosome:[7 6 5 5 2 5 3 0]  Fitness:19
# Chromosome:[5 4 5 1 5 4 0 0]  Fitness:19
# Chromosome:[3 5 7 4 1 6 2 7]  Fitness:26
# Chromosome:[5 6 7 7 2 4 3 0]  Fitness:20
# Chromosome:[7 0 1 7 2 4 0 1]  Fitness:20
# Chromosome:[2 6 3 6 1 4 6 0]  Fitness:22
# Chromosome:[5 4 4 4 2 4 0 0]  Fitness:16
# Chromosome:[7 0 2 7 2 4 2 7]  Fitness:20
#
# Chromosome:[3 6 7 7 2 4 3 0]  Fitness:21
# Chromosome:[5 5 7 4 1 6 2 7]  Fitness:23
# Chromosome:[2 6 3 6 5 4 6 0]  Fitness:20
# Chromosome:[5 6 4 4 2 4 0 0]  Fitness:17
# Chromosome:[5 4 4 7 2 4 2 7]  Fitness:21
# Chromosome:[5 0 2 4 2 4 0 0]  Fitness:20
# Chromosome:[5 6 7 7 5 4 0 1]  Fitness:19
# Chromosome:[7 0 0 7 2 4 3 0]  Fitness:20
#
# Chromosome:[5 1 2 4 2 4 0 1]  Fitness:22
# Chromosome:[5 6 7 7 5 5 0 0]  Fitness:17
# Chromosome:[5 6 4 4 2 4 2 5]  Fitness:19
# Chromosome:[5 4 0 7 2 4 0 0]  Fitness:21
# Chromosome:[2 6 3 5 5 4 0 0]  Fitness:22
# Chromosome:[5 6 4 4 2 6 6 0]  Fitness:18
# Chromosome:[5 5 7 4 5 4 6 4]  Fitness:17
# Chromosome:[2 6 3 6 2 6 2 7]  Fitness:21
#
# Chromosome:[5 6 4 4 5 7 6 4]  Fitness:18
# Chromosome:[5 5 7 4 4 6 6 0]  Fitness:21
# Chromosome:[5 5 7 5 5 6 2 7]  Fitness:17
# Chromosome:[2 6 3 7 2 4 6 4]  Fitness:25
# Chromosome:[5 2 0 7 2 4 0 0]  Fitness:22
# Chromosome:[5 4 4 4 2 4 2 5]  Fitness:17
# Chromosome:[5 4 7 7 2 4 0 0]  Fitness:21
# Chromosome:[2 7 3 5 5 4 0 0]  Fitness:22
#
# Chromosome:[5 6 6 7 2 4 6 4]  Fitness:22
# Chromosome:[2 5 7 5 5 6 2 1]  Fitness:18
# Chromosome:[5 2 0 7 2 4 1 0]  Fitness:24
# Chromosome:[5 4 4 3 2 4 2 5]  Fitness:18
# Chromosome:[2 6 0 7 2 4 0 0]  Fitness:20
# Chromosome:[5 2 0 0 2 4 6 4]  Fitness:22
# Chromosome:[0 4 7 7 2 4 0 0]  Fitness:21
# Chromosome:[2 0 3 5 5 4 0 0]  Fitness:20
#
# Chromosome:[0 4 5 5 5 4 0 0]  Fitness:18
# Chromosome:[2 0 7 7 2 4 3 0]  Fitness:21
# Chromosome:[2 5 7 5 7 4 1 0]  Fitness:23
# Chromosome:[5 2 0 7 5 6 7 1]  Fitness:20
# Chromosome:[2 6 0 0 2 4 6 4]  Fitness:21
# Chromosome:[1 2 0 7 2 4 0 0]  Fitness:21
# Chromosome:[2 2 0 0 2 4 0 0]  Fitness:15
# Chromosome:[0 4 7 7 5 4 6 4]  Fitness:20
#
# Chromosome:[1 2 0 7 2 4 0 7]  Fitness:22
# Chromosome:[3 2 0 0 2 4 0 0]  Fitness:16
# Chromosome:[2 0 7 5 7 4 7 1]  Fitness:21
# Chromosome:[5 2 7 7 5 6 1 0]  Fitness:20
# Chromosome:[5 5 0 7 5 4 6 4]  Fitness:22
# Chromosome:[2 6 6 0 2 6 7 1]  Fitness:22
# Chromosome:[2 0 7 7 2 4 1 2]  Fitness:19
# Chromosome:[2 5 7 5 7 5 3 0]  Fitness:22
#
# Chromosome:[5 7 6 0 2 6 7 1]  Fitness:22
# Chromosome:[2 5 0 7 6 4 6 4]  Fitness:22
# Chromosome:[5 0 7 7 2 4 1 2]  Fitness:20
# Chromosome:[6 5 7 5 7 5 3 0]  Fitness:22
# Chromosome:[5 2 7 7 3 6 1 0]  Fitness:22
# Chromosome:[5 5 0 7 5 7 6 4]  Fitness:22
# Chromosome:[2 0 7 5 7 6 1 6]  Fitness:23
# Chromosome:[5 2 7 7 5 1 7 1]  Fitness:18
#
# Chromosome:[3 0 7 5 7 5 3 0]  Fitness:22
# Chromosome:[6 5 5 7 2 4 1 2]  Fitness:19
# Chromosome:[5 0 7 5 7 6 1 6]  Fitness:22
# Chromosome:[2 3 0 7 5 7 6 4]  Fitness:22
# Chromosome:[2 5 0 7 6 6 1 2]  Fitness:21
# Chromosome:[5 0 6 7 2 4 6 4]  Fitness:24
# Chromosome:[5 2 5 7 3 7 6 4]  Fitness:24
# Chromosome:[5 5 0 7 5 6 1 0]  Fitness:21
#
# Chromosome:[6 5 5 7 7 2 1 6]  Fitness:19
# Chromosome:[1 0 7 5 2 4 1 2]  Fitness:20
# Chromosome:[2 3 0 7 5 7 1 4]  Fitness:23
# Chromosome:[2 5 0 7 4 6 6 4]  Fitness:22
# Chromosome:[5 0 0 7 5 7 6 4]  Fitness:24
# Chromosome:[2 2 7 5 7 6 1 6]  Fitness:22
# Chromosome:[2 5 0 7 2 4 5 4]  Fitness:19
# Chromosome:[5 0 6 7 6 6 1 3]  Fitness:21
#
# Chromosome:[1 0 6 7 6 6 1 3]  Fitness:18
# Chromosome:[5 5 0 7 2 4 5 0]  Fitness:20
# Chromosome:[2 5 0 7 1 6 6 4]  Fitness:23
# Chromosome:[5 0 4 7 5 7 6 4]  Fitness:23
# Chromosome:[2 3 0 7 5 4 6 4]  Fitness:24
# Chromosome:[2 5 0 7 4 6 0 4]  Fitness:22
# Chromosome:[2 2 0 7 2 3 5 4]  Fitness:20
# Chromosome:[1 5 7 5 7 6 1 6]  Fitness:22
#
# Chromosome:[2 0 4 7 5 7 6 4]  Fitness:22
# Chromosome:[5 5 0 6 1 6 6 4]  Fitness:21
# Chromosome:[2 2 0 7 2 3 5 6]  Fitness:20
# Chromosome:[1 5 7 5 3 6 1 4]  Fitness:23
# Chromosome:[1 0 4 7 5 7 6 4]  Fitness:22
# Chromosome:[2 3 0 7 5 2 6 4]  Fitness:24
# Chromosome:[2 6 0 7 4 3 5 4]  Fitness:23
# Chromosome:[2 2 0 7 2 6 0 4]  Fitness:19
#
# Chromosome:[1 0 7 7 5 7 6 4]  Fitness:21
# Chromosome:[1 5 7 5 3 6 7 4]  Fitness:22
# Chromosome:[2 6 0 7 2 6 0 4]  Fitness:21
# Chromosome:[1 2 0 7 4 3 5 4]  Fitness:23
# Chromosome:[2 3 0 7 5 3 4 4]  Fitness:20
# Chromosome:[2 6 0 7 4 2 6 1]  Fitness:22
# Chromosome:[3 3 0 7 5 2 6 4]  Fitness:26
# Chromosome:[2 1 4 7 5 7 6 4]  Fitness:20
#
# Chromosome:[2 3 0 7 5 3 4 4]  Fitness:20
# Chromosome:[1 3 0 7 4 3 5 4]  Fitness:23
# Chromosome:[3 3 3 7 5 7 6 4]  Fitness:21
# Chromosome:[5 1 4 7 5 2 6 4]  Fitness:24
# Chromosome:[2 6 0 7 5 2 6 4]  Fitness:23
# Chromosome:[3 3 0 7 4 2 6 1]  Fitness:25
# Chromosome:[2 6 0 7 4 7 6 1]  Fitness:21
# Chromosome:[2 3 0 7 5 3 1 4]  Fitness:24
#
# Chromosome:[3 3 6 7 5 2 6 4]  Fitness:24
# Chromosome:[5 1 6 7 5 7 6 4]  Fitness:22
# Chromosome:[2 6 0 3 4 7 6 1]  Fitness:20
# Chromosome:[6 3 0 7 5 3 1 4]  Fitness:26
# Chromosome:[1 6 0 7 5 2 6 1]  Fitness:24
# Chromosome:[3 3 0 7 4 2 0 4]  Fitness:24
# Chromosome:[1 3 0 7 4 1 6 4]  Fitness:25
# Chromosome:[6 3 3 7 5 3 5 4]  Fitness:22
#
# Chromosome:[1 3 3 7 5 3 5 4]  Fitness:20
# Chromosome:[6 5 0 7 4 1 6 4]  Fitness:21
# Chromosome:[2 0 0 3 5 3 1 4]  Fitness:24
# Chromosome:[1 3 0 7 4 7 6 1]  Fitness:22
# Chromosome:[6 3 0 7 6 3 6 1]  Fitness:20
# Chromosome:[1 6 0 7 5 6 1 4]  Fitness:21
# Chromosome:[1 6 5 7 5 2 6 1]  Fitness:21
# Chromosome:[3 3 0 7 4 2 0 4]  Fitness:24
#
# Chromosome:[1 6 7 7 5 2 6 1]  Fitness:21
# Chromosome:[1 6 5 7 5 6 1 4]  Fitness:18
# Chromosome:[6 5 0 2 4 3 1 4]  Fitness:24
# Chromosome:[2 0 0 3 7 1 6 4]  Fitness:23
# Chromosome:[2 0 0 3 5 3 1 4]  Fitness:24
# Chromosome:[4 3 0 7 4 7 6 1]  Fitness:20
# Chromosome:[6 0 0 7 5 6 1 4]  Fitness:24
# Chromosome:[1 6 0 7 6 3 6 3]  Fitness:20
#
# Chromosome:[6 0 0 2 6 3 6 3]  Fitness:20
# Chromosome:[1 6 0 1 5 6 1 4]  Fitness:18
# Chromosome:[1 5 0 2 0 3 1 4]  Fitness:25
# Chromosome:[6 6 5 7 5 6 1 6]  Fitness:17
# Chromosome:[6 5 0 2 4 6 6 4]  Fitness:21
# Chromosome:[2 0 0 3 7 4 1 4]  Fitness:23
# Chromosome:[5 3 0 7 4 7 1 4]  Fitness:25
# Chromosome:[6 0 1 7 5 6 6 1]  Fitness:22
#
# Chromosome:[6 6 5 7 4 6 6 4]  Fitness:18
# Chromosome:[6 5 0 2 4 3 1 6]  Fitness:23
# Chromosome:[5 3 0 7 5 6 6 1]  Fitness:25
# Chromosome:[6 0 1 7 5 7 6 4]  Fitness:24
# Chromosome:[6 5 0 1 4 4 1 4]  Fitness:22
# Chromosome:[2 0 5 3 7 6 6 4]  Fitness:22
# Chromosome:[1 5 0 7 5 6 1 6]  Fitness:21
# Chromosome:[6 6 5 2 0 3 1 5]  Fitness:22
#
# Chromosome:[6 3 1 7 5 6 6 1]  Fitness:23
# Chromosome:[5 5 0 2 0 3 1 6]  Fitness:23
# Chromosome:[0 0 5 3 5 6 1 6]  Fitness:21
# Chromosome:[1 5 0 7 7 6 6 5]  Fitness:20
# Chromosome:[6 0 1 7 5 7 6 2]  Fitness:23
# Chromosome:[6 5 0 1 4 4 1 1]  Fitness:21
# Chromosome:[5 3 0 4 5 7 6 4]  Fitness:23
# Chromosome:[6 4 1 7 5 6 6 1]  Fitness:23
#
# Chromosome:[5 3 0 4 5 7 4 4]  Fitness:21
# Chromosome:[6 4 1 7 5 6 6 1]  Fitness:23
# Chromosome:[5 3 7 4 5 7 6 4]  Fitness:20
# Chromosome:[6 6 0 1 4 4 1 1]  Fitness:20
# Chromosome:[0 0 5 7 7 6 6 7]  Fitness:18
# Chromosome:[1 5 0 3 5 6 1 1]  Fitness:20
# Chromosome:[6 0 1 7 5 7 6 1]  Fitness:23
# Chromosome:[6 5 0 1 4 4 6 2]  Fitness:22
#
# Chromosome:[5 6 0 1 4 4 1 1]  Fitness:20
# Chromosome:[6 6 7 4 5 7 6 4]  Fitness:18
# Chromosome:[1 5 0 4 5 7 6 1]  Fitness:22
# Chromosome:[6 0 1 3 5 6 1 3]  Fitness:22
# Chromosome:[0 5 0 3 5 2 1 1]  Fitness:22
# Chromosome:[1 0 5 7 7 6 6 7]  Fitness:19
# Chromosome:[6 5 0 1 4 6 6 7]  Fitness:20
# Chromosome:[0 0 5 7 7 4 1 1]  Fitness:22
#
# Chromosome:[6 0 2 3 5 2 1 1]  Fitness:23
# Chromosome:[0 7 0 3 5 6 1 3]  Fitness:24
# Chromosome:[0 5 5 4 7 6 6 7]  Fitness:18
# Chromosome:[1 5 0 3 5 2 1 1]  Fitness:21
# Chromosome:[1 5 5 7 7 6 6 7]  Fitness:18
# Chromosome:[6 5 0 1 4 6 6 7]  Fitness:20
# Chromosome:[6 6 4 4 5 7 6 1]  Fitness:19
# Chromosome:[1 5 1 4 5 7 6 4]  Fitness:21
#
# Chromosome:[0 5 3 4 5 2 1 1]  Fitness:20
# Chromosome:[1 5 3 3 7 6 6 7]  Fitness:17
# Chromosome:[1 5 0 3 5 6 6 7]  Fitness:19
# Chromosome:[1 5 5 7 7 0 1 1]  Fitness:19
# Chromosome:[1 5 5 7 7 6 7 7]  Fitness:15
# Chromosome:[6 5 5 1 4 6 6 7]  Fitness:20
# Chromosome:[5 5 0 4 5 7 6 1]  Fitness:23
# Chromosome:[6 6 4 3 4 6 6 7]  Fitness:12
#
# Chromosome:[1 5 5 7 7 6 1 1]  Fitness:18
# Chromosome:[1 5 0 3 5 6 6 7]  Fitness:19
# Chromosome:[1 5 5 7 4 6 7 7]  Fitness:19
# Chromosome:[1 5 5 7 1 0 1 1]  Fitness:17
# Chromosome:[6 5 0 6 5 7 6 1]  Fitness:21
# Chromosome:[5 5 5 1 6 6 6 7]  Fitness:21
# Chromosome:[5 6 4 3 4 6 6 7]  Fitness:16
# Chromosome:[6 5 6 4 5 7 6 1]  Fitness:19
#
# Chromosome:[5 5 5 1 6 6 6 7]  Fitness:21
# Chromosome:[5 6 2 3 4 6 6 7]  Fitness:14
# Chromosome:[6 5 5 7 1 0 1 1]  Fitness:19
# Chromosome:[6 5 5 7 4 6 7 7]  Fitness:19
# Chromosome:[6 5 7 1 6 6 6 7]  Fitness:19
# Chromosome:[5 5 0 6 5 7 6 1]  Fitness:22
# Chromosome:[1 5 0 4 5 6 6 7]  Fitness:19
# Chromosome:[1 5 5 7 4 6 3 7]  Fitness:23
#
# Chromosome:[6 5 0 6 5 7 6 4]  Fitness:21
# Chromosome:[5 5 7 1 6 6 4 7]  Fitness:22
# Chromosome:[6 5 5 7 5 6 7 7]  Fitness:16
# Chromosome:[6 5 7 1 1 6 6 7]  Fitness:21
# Chromosome:[5 6 5 7 1 0 1 3]  Fitness:17
# Chromosome:[6 5 2 3 4 3 6 7]  Fitness:12
# Chromosome:[1 5 5 7 4 6 4 7]  Fitness:21
# Chromosome:[1 5 0 4 5 6 6 7]  Fitness:19
#
# Chromosome:[6 5 7 1 1 6 7 7]  Fitness:21
# Chromosome:[6 5 0 7 5 6 7 7]  Fitness:18
# Chromosome:[5 6 5 7 1 0 1 3]  Fitness:17
# Chromosome:[6 5 0 3 4 3 6 7]  Fitness:15
# Chromosome:[1 4 0 4 5 6 6 7]  Fitness:19
# Chromosome:[1 5 5 7 4 6 4 7]  Fitness:21
# Chromosome:[5 5 2 1 6 6 4 7]  Fitness:22
# Chromosome:[6 0 5 7 5 6 7 7]  Fitness:20
#
# Chromosome:[1 5 5 0 6 6 4 7]  Fitness:24
# Chromosome:[5 7 2 1 4 6 4 7]  Fitness:20
# Chromosome:[1 5 5 7 4 6 4 1]  Fitness:21
# Chromosome:[1 4 0 4 5 6 6 3]  Fitness:20
# Chromosome:[6 5 0 1 5 6 6 7]  Fitness:20
# Chromosome:[1 4 0 4 1 3 6 7]  Fitness:22
# Chromosome:[5 3 5 7 1 0 1 3]  Fitness:19
# Chromosome:[6 5 0 3 4 2 6 7]  Fitness:18
#
# Chromosome:[5 6 2 1 4 6 4 1]  Fitness:20
# Chromosome:[1 5 5 7 4 6 4 6]  Fitness:22
# Chromosome:[5 3 5 7 4 4 6 7]  Fitness:22
# Chromosome:[6 5 0 3 1 3 1 3]  Fitness:20
# Chromosome:[1 4 0 1 5 6 6 4]  Fitness:20
# Chromosome:[6 5 3 4 5 6 6 3]  Fitness:16
# Chromosome:[1 4 0 4 1 5 6 7]  Fitness:21
# Chromosome:[6 5 0 1 5 6 4 7]  Fitness:21
#
# Chromosome:[5 5 0 7 1 3 1 3]  Fitness:21
# Chromosome:[1 3 5 7 4 4 6 7]  Fitness:23
# Chromosome:[6 3 0 3 1 3 1 3]  Fitness:19
# Chromosome:[1 4 0 1 5 6 2 4]  Fitness:21
# Chromosome:[1 4 1 1 5 6 6 3]  Fitness:21
# Chromosome:[6 5 3 4 5 6 5 4]  Fitness:13
# Chromosome:[6 5 3 4 2 5 6 7]  Fitness:19
# Chromosome:[3 4 0 4 5 6 6 3]  Fitness:21
#
# Chromosome:[6 5 3 4 5 5 6 0]  Fitness:18
# Chromosome:[6 5 3 0 2 6 5 4]  Fitness:18
# Chromosome:[1 4 1 1 5 6 5 4]  Fitness:16
# Chromosome:[6 5 3 5 5 6 6 3]  Fitness:17
# Chromosome:[6 5 3 1 5 6 6 3]  Fitness:19
# Chromosome:[3 4 0 4 2 5 6 7]  Fitness:22
# Chromosome:[6 3 0 3 1 1 2 4]  Fitness:21
# Chromosome:[1 4 0 1 5 6 1 3]  Fitness:21
#
# Chromosome:[2 4 0 1 5 6 1 3]  Fitness:24
# Chromosome:[6 3 0 3 2 1 2 4]  Fitness:18
# Chromosome:[6 4 0 4 2 5 2 7]  Fitness:23
# Chromosome:[3 5 3 3 5 6 6 3]  Fitness:15
# Chromosome:[3 4 0 4 2 0 6 7]  Fitness:22
# Chromosome:[6 3 0 3 1 1 2 4]  Fitness:21
# Chromosome:[6 5 3 5 5 7 6 3]  Fitness:19
# Chromosome:[6 6 3 1 5 6 6 3]  Fitness:18
#
# Chromosome:[6 5 3 5 5 2 6 3]  Fitness:21
# Chromosome:[6 6 3 1 5 6 0 3]  Fitness:20
# Chromosome:[0 4 0 4 2 5 2 7]  Fitness:21
# Chromosome:[6 3 0 3 2 1 5 4]  Fitness:19
# Chromosome:[3 5 0 4 2 1 2 4]  Fitness:21
# Chromosome:[6 3 0 3 1 0 6 7]  Fitness:20
# Chromosome:[3 5 2 3 5 6 6 3]  Fitness:18
# Chromosome:[3 4 0 4 2 0 6 6]  Fitness:22
#
# Chromosome:[3 5 0 3 1 5 6 7]  Fitness:19
# Chromosome:[6 3 0 4 2 1 5 4]  Fitness:22
# Chromosome:[0 4 0 4 2 1 5 4]  Fitness:21
# Chromosome:[6 3 0 3 2 5 2 4]  Fitness:21
# Chromosome:[6 4 0 4 2 5 7 7]  Fitness:22
# Chromosome:[0 6 3 1 5 6 0 2]  Fitness:22
# Chromosome:[3 3 0 4 2 0 6 6]  Fitness:24
# Chromosome:[3 5 2 3 5 6 6 6]  Fitness:18
#
# Chromosome:[0 6 3 7 5 6 0 6]  Fitness:21
# Chromosome:[3 3 0 4 2 0 6 2]  Fitness:23
# Chromosome:[0 1 0 4 2 5 2 4]  Fitness:20
# Chromosome:[6 3 0 1 2 1 5 4]  Fitness:19
# Chromosome:[6 3 0 4 0 1 5 4]  Fitness:22
# Chromosome:[0 4 0 4 2 1 6 4]  Fitness:21
# Chromosome:[6 3 0 6 2 5 2 4]  Fitness:24
# Chromosome:[6 5 0 4 2 5 7 7]  Fitness:20
#
# Chromosome:[6 3 0 4 2 1 5 4]  Fitness:22
# Chromosome:[0 4 0 4 0 1 7 4]  Fitness:20
# Chromosome:[6 3 0 1 2 4 5 4]  Fitness:20
# Chromosome:[6 3 5 4 0 1 5 4]  Fitness:21
# Chromosome:[6 3 0 4 2 5 7 7]  Fitness:23
# Chromosome:[2 5 0 6 2 5 2 4]  Fitness:21
# Chromosome:[5 3 0 4 2 0 6 4]  Fitness:24
# Chromosome:[0 1 0 4 2 3 2 2]  Fitness:18
#
# Chromosome:[6 3 0 4 2 5 2 5]  Fitness:22
# Chromosome:[2 5 0 6 2 5 7 0]  Fitness:22
# Chromosome:[5 3 1 4 2 0 2 2]  Fitness:23
# Chromosome:[0 1 0 4 3 3 6 4]  Fitness:19
# Chromosome:[6 3 5 1 0 1 5 4]  Fitness:20
# Chromosome:[6 3 0 4 2 0 7 7]  Fitness:23
# Chromosome:[2 5 0 0 2 5 6 4]  Fitness:20
# Chromosome:[5 3 0 4 2 0 2 4]  Fitness:23
#
# Chromosome:[0 5 0 4 0 1 5 4]  Fitness:20
# Chromosome:[6 3 5 1 3 3 6 4]  Fitness:21
# Chromosome:[2 5 0 6 2 5 2 1]  Fitness:20
# Chromosome:[5 3 1 5 2 0 7 0]  Fitness:24
# Chromosome:[6 3 0 0 2 5 1 4]  Fitness:24
# Chromosome:[4 5 0 4 2 0 7 7]  Fitness:21
# Chromosome:[7 3 5 1 0 1 5 4]  Fitness:20
# Chromosome:[6 3 0 4 2 2 7 7]  Fitness:22
#
# Chromosome:[7 3 0 0 2 0 7 7]  Fitness:21
# Chromosome:[4 5 2 4 2 5 1 4]  Fitness:18
# Chromosome:[1 3 0 4 2 2 7 7]  Fitness:21
# Chromosome:[6 3 5 1 0 1 5 4]  Fitness:20
# Chromosome:[6 3 0 0 2 5 1 3]  Fitness:23
# Chromosome:[5 3 7 5 2 0 7 0]  Fitness:22
# Chromosome:[2 5 0 6 3 5 7 0]  Fitness:24
# Chromosome:[5 3 1 5 2 0 2 1]  Fitness:20
#
# Chromosome:[6 3 4 0 2 0 7 0]  Fitness:21
# Chromosome:[5 3 7 5 2 6 1 3]  Fitness:24
# Chromosome:[2 5 0 6 3 5 7 1]  Fitness:26
# Chromosome:[5 3 7 6 2 0 7 0]  Fitness:23
# Chromosome:[7 5 2 4 2 2 7 7]  Fitness:16
# Chromosome:[1 1 0 4 2 5 1 4]  Fitness:19
# Chromosome:[2 5 0 6 3 5 7 0]  Fitness:24
# Chromosome:[5 3 1 5 2 0 2 1]  Fitness:20
#
# Chromosome:[5 3 2 4 2 2 7 7]  Fitness:20
# Chromosome:[7 5 7 6 2 0 7 0]  Fitness:21
# Chromosome:[2 5 1 6 2 0 7 0]  Fitness:25
# Chromosome:[5 3 0 0 3 5 7 1]  Fitness:25
# Chromosome:[0 3 1 5 2 0 2 1]  Fitness:21
# Chromosome:[2 5 0 6 3 2 7 0]  Fitness:22
# Chromosome:[5 3 7 6 3 5 7 1]  Fitness:23
# Chromosome:[2 5 0 4 2 6 1 3]  Fitness:22
#
# Chromosome:[2 5 1 6 4 0 7 0]  Fitness:27
# Chromosome:[7 0 7 6 2 0 7 0]  Fitness:20
# Chromosome:[5 3 0 0 5 0 2 1]  Fitness:22
# Chromosome:[0 3 1 5 2 3 7 1]  Fitness:21
# Chromosome:[0 3 1 2 2 0 2 1]  Fitness:20
# Chromosome:[7 5 0 6 3 2 7 0]  Fitness:20
# Chromosome:[2 5 1 6 3 5 7 4]  Fitness:26
# Chromosome:[5 3 0 0 2 0 7 0]  Fitness:20
#
# Chromosome:[0 3 1 2 2 0 2 6]  Fitness:20
# Chromosome:[7 5 0 6 4 2 7 1]  Fitness:25
# Chromosome:[7 0 7 6 2 0 2 1]  Fitness:23
# Chromosome:[5 2 0 0 5 0 7 0]  Fitness:16
# Chromosome:[5 3 0 0 5 0 7 2]  Fitness:20
# Chromosome:[0 7 1 5 2 3 2 1]  Fitness:15
# Chromosome:[1 3 1 5 2 0 2 1]  Fitness:20
# Chromosome:[0 3 1 2 1 3 7 1]  Fitness:21
#
# Chromosome:[7 5 0 6 2 4 2 1]  Fitness:23
# Chromosome:[7 0 7 6 4 2 7 1]  Fitness:22
# Chromosome:[5 2 0 0 5 0 7 2]  Fitness:16
# Chromosome:[5 3 0 0 5 0 7 1]  Fitness:22
# Chromosome:[7 0 7 5 5 0 7 0]  Fitness:18
# Chromosome:[5 2 0 6 2 0 3 1]  Fitness:23
# Chromosome:[1 3 1 5 2 0 7 1]  Fitness:22
# Chromosome:[0 3 1 2 1 3 2 7]  Fitness:21
#
# Chromosome:[7 2 7 6 4 2 7 1]  Fitness:20
# Chromosome:[4 2 0 0 5 0 7 2]  Fitness:18
# Chromosome:[5 2 0 0 5 0 7 6]  Fitness:18
# Chromosome:[5 3 0 0 1 0 7 2]  Fitness:20
# Chromosome:[7 0 0 5 2 0 3 1]  Fitness:23
# Chromosome:[5 2 0 5 5 0 7 0]  Fitness:18
# Chromosome:[5 2 0 6 2 0 0 1]  Fitness:20
# Chromosome:[1 1 1 5 2 0 7 1]  Fitness:20
#
# Chromosome:[4 2 0 0 5 1 7 2]  Fitness:21
# Chromosome:[5 2 0 0 5 1 7 6]  Fitness:21
# Chromosome:[1 3 0 0 1 0 7 2]  Fitness:20
# Chromosome:[5 2 2 0 5 0 7 6]  Fitness:19
# Chromosome:[7 0 6 5 5 0 7 0]  Fitness:20
# Chromosome:[5 0 0 5 2 0 3 1]  Fitness:21
# Chromosome:[5 2 0 6 2 0 0 1]  Fitness:20
# Chromosome:[5 2 0 5 5 3 7 0]  Fitness:19
#
# Chromosome:[1 3 6 0 5 0 7 6]  Fitness:22
# Chromosome:[1 2 2 0 1 0 7 2]  Fitness:16
# Chromosome:[5 1 0 5 5 3 7 0]  Fitness:20
# Chromosome:[1 2 0 6 2 0 0 1]  Fitness:19
# Chromosome:[7 0 0 5 2 0 3 5]  Fitness:21
# Chromosome:[4 0 6 5 5 0 7 0]  Fitness:21
# Chromosome:[5 2 1 0 1 0 7 2]  Fitness:16
# Chromosome:[1 6 0 0 5 1 7 6]  Fitness:21
#
# Chromosome:[5 0 0 5 2 0 3 0]  Fitness:19
# Chromosome:[4 0 6 5 0 0 7 5]  Fitness:21
# Chromosome:[1 2 2 5 0 3 7 0]  Fitness:21
# Chromosome:[5 1 0 0 1 0 5 2]  Fitness:17
# Chromosome:[1 2 0 6 1 0 0 1]  Fitness:19
# Chromosome:[7 0 0 2 2 0 3 5]  Fitness:19
# Chromosome:[4 0 6 5 5 0 5 0]  Fitness:19
# Chromosome:[5 2 1 0 1 2 7 2]  Fitness:16
#
# Chromosome:[4 0 6 5 0 3 7 1]  Fitness:19
# Chromosome:[1 3 2 5 0 0 7 5]  Fitness:21
# Chromosome:[1 2 0 2 2 0 4 5]  Fitness:16
# Chromosome:[7 0 0 6 5 0 0 1]  Fitness:20
# Chromosome:[5 2 1 0 1 2 7 1]  Fitness:16
# Chromosome:[0 0 6 5 5 0 5 0]  Fitness:17
# Chromosome:[5 1 0 1 1 0 0 1]  Fitness:13
# Chromosome:[1 7 0 0 1 0 5 2]  Fitness:21
#
# Chromosome:[0 0 0 1 3 0 0 1]  Fitness:14
# Chromosome:[5 1 0 5 5 0 5 0]  Fitness:17
# Chromosome:[5 2 6 5 5 0 5 1]  Fitness:17
# Chromosome:[6 0 1 0 1 2 7 1]  Fitness:19
# Chromosome:[7 0 0 6 5 0 0 6]  Fitness:19
# Chromosome:[5 2 1 0 1 6 7 1]  Fitness:17
# Chromosome:[1 2 0 6 5 0 0 7]  Fitness:21
# Chromosome:[7 0 0 2 2 7 4 5]  Fitness:17
#
# Chromosome:[7 0 0 6 5 0 0 4]  Fitness:21
# Chromosome:[6 0 1 0 1 2 2 1]  Fitness:17
# Chromosome:[5 2 6 5 5 0 4 1]  Fitness:20
# Chromosome:[6 0 1 2 1 2 7 1]  Fitness:19
# Chromosome:[5 2 1 0 1 4 7 1]  Fitness:18
# Chromosome:[1 2 0 6 5 0 0 7]  Fitness:21
# Chromosome:[1 2 1 6 2 7 4 5]  Fitness:20
# Chromosome:[7 6 0 2 5 0 0 7]  Fitness:22
#
# Chromosome:[1 3 1 6 2 7 4 5]  Fitness:22
# Chromosome:[1 2 0 6 5 0 5 7]  Fitness:22
# Chromosome:[6 2 1 0 1 4 7 1]  Fitness:19
# Chromosome:[5 0 1 2 1 2 7 1]  Fitness:17
# Chromosome:[5 0 1 2 1 2 6 1]  Fitness:17
# Chromosome:[6 2 6 5 5 0 4 1]  Fitness:22
# Chromosome:[1 2 3 6 5 0 0 7]  Fitness:19
# Chromosome:[5 2 1 0 1 4 7 1]  Fitness:18
#
# Chromosome:[1 2 0 0 5 0 5 1]  Fitness:19
# Chromosome:[6 2 1 6 1 4 7 7]  Fitness:21
# Chromosome:[5 2 1 0 6 4 7 1]  Fitness:22
# Chromosome:[1 2 3 1 5 0 0 7]  Fitness:19
# Chromosome:[5 0 1 2 1 2 6 6]  Fitness:15
# Chromosome:[5 0 1 2 1 0 7 1]  Fitness:15
# Chromosome:[6 2 6 5 5 0 4 3]  Fitness:23
# Chromosome:[1 2 3 6 5 0 0 7]  Fitness:19
#
# Chromosome:[1 5 3 1 5 0 0 7]  Fitness:20
# Chromosome:[5 2 1 0 6 4 3 1]  Fitness:21
# Chromosome:[5 0 1 2 7 2 6 1]  Fitness:22
# Chromosome:[5 0 1 4 1 0 7 6]  Fitness:18
# Chromosome:[6 2 1 4 6 4 7 1]  Fitness:20
# Chromosome:[5 2 1 6 1 6 7 7]  Fitness:20
# Chromosome:[5 3 6 5 5 0 4 3]  Fitness:20
# Chromosome:[6 7 1 2 1 0 7 1]  Fitness:18
#
# Chromosome:[6 2 1 4 7 4 7 7]  Fitness:19
# Chromosome:[5 2 1 5 1 6 7 1]  Fitness:18
# Chromosome:[5 2 1 1 5 0 4 3]  Fitness:21
# Chromosome:[5 6 6 5 1 6 7 7]  Fitness:19
# Chromosome:[5 2 1 4 6 4 7 1]  Fitness:21
# Chromosome:[6 2 1 4 1 0 7 6]  Fitness:19
# Chromosome:[5 3 6 5 1 0 7 1]  Fitness:19
# Chromosome:[6 7 1 5 5 0 4 3]  Fitness:24
#
# Chromosome:[5 2 1 5 1 6 7 7]  Fitness:20
# Chromosome:[5 6 6 1 5 1 4 3]  Fitness:21
# Chromosome:[5 3 6 5 7 0 7 1]  Fitness:21
# Chromosome:[6 2 1 2 1 0 7 6]  Fitness:16
# Chromosome:[5 2 1 3 1 0 7 6]  Fitness:20
# Chromosome:[6 2 1 4 0 4 7 1]  Fitness:21
# Chromosome:[5 2 1 1 5 0 4 3]  Fitness:21
# Chromosome:[5 2 1 5 1 4 7 1]  Fitness:19
#
# Chromosome:[5 3 1 2 2 0 7 6]  Fitness:20
# Chromosome:[6 2 3 5 7 0 7 1]  Fitness:22
# Chromosome:[6 2 1 2 1 0 3 6]  Fitness:17
# Chromosome:[5 2 1 3 1 2 7 6]  Fitness:20
# Chromosome:[5 6 1 5 7 0 7 1]  Fitness:22
# Chromosome:[5 3 6 2 5 1 4 3]  Fitness:23
# Chromosome:[6 2 1 1 1 4 7 1]  Fitness:19
# Chromosome:[5 2 1 5 5 0 4 3]  Fitness:21
#
# Chromosome:[6 4 1 2 1 0 7 6]  Fitness:16
# Chromosome:[5 7 1 3 1 2 3 6]  Fitness:21
# Chromosome:[6 2 1 4 1 0 3 6]  Fitness:21
# Chromosome:[6 4 3 5 7 0 7 1]  Fitness:21
# Chromosome:[0 2 1 3 1 2 7 1]  Fitness:20
# Chromosome:[5 3 1 5 7 0 7 6]  Fitness:22
# Chromosome:[6 2 5 1 5 0 4 3]  Fitness:24
# Chromosome:[5 2 2 5 1 4 7 1]  Fitness:22
#
# Chromosome:[0 2 1 3 2 2 7 6]  Fitness:19
# Chromosome:[5 3 1 5 7 0 1 1]  Fitness:20
# Chromosome:[6 7 1 5 7 0 7 1]  Fitness:20
# Chromosome:[6 4 3 4 1 1 3 6]  Fitness:18
# Chromosome:[6 4 3 5 7 0 7 1]  Fitness:21
# Chromosome:[7 2 1 3 1 2 7 1]  Fitness:19
# Chromosome:[6 2 1 4 1 6 3 6]  Fitness:18
# Chromosome:[5 7 1 3 1 4 3 6]  Fitness:20
#
# Chromosome:[6 7 1 0 1 1 3 6]  Fitness:17
# Chromosome:[6 4 3 2 7 0 7 1]  Fitness:19
# Chromosome:[6 2 1 4 1 6 3 5]  Fitness:21
# Chromosome:[5 7 1 3 1 4 7 6]  Fitness:21
# Chromosome:[7 2 1 3 1 2 7 6]  Fitness:19
# Chromosome:[6 2 7 4 1 6 3 1]  Fitness:21
# Chromosome:[6 4 6 5 7 0 7 1]  Fitness:21
# Chromosome:[6 4 3 4 1 1 3 6]  Fitness:18
#
# Chromosome:[6 4 3 4 1 1 1 6]  Fitness:17
# Chromosome:[6 4 6 5 7 3 7 1]  Fitness:19
# Chromosome:[6 2 7 4 1 3 3 1]  Fitness:22
# Chromosome:[6 4 6 5 7 0 7 4]  Fitness:21
# Chromosome:[5 7 1 3 1 2 6 6]  Fitness:22
# Chromosome:[7 2 1 3 1 4 3 6]  Fitness:20
# Chromosome:[6 2 1 4 1 0 3 5]  Fitness:23
# Chromosome:[5 7 1 3 1 4 1 6]  Fitness:21
#
# Chromosome:[6 5 6 5 7 0 6 6]  Fitness:18
# Chromosome:[5 2 1 3 1 2 7 4]  Fitness:20
# Chromosome:[7 2 1 3 1 5 3 5]  Fitness:22
# Chromosome:[6 2 1 4 1 0 3 6]  Fitness:21
# Chromosome:[6 2 1 2 1 4 1 6]  Fitness:15
# Chromosome:[7 7 1 4 1 0 3 5]  Fitness:23
# Chromosome:[5 5 1 3 1 4 3 6]  Fitness:18
# Chromosome:[7 7 1 3 1 2 6 2]  Fitness:22
#
# Chromosome:[6 2 0 2 1 4 1 6]  Fitness:21
# Chromosome:[7 7 1 4 1 0 2 5]  Fitness:23
# Chromosome:[5 2 4 3 1 5 3 5]  Fitness:20
# Chromosome:[3 2 1 3 1 2 7 4]  Fitness:18
# Chromosome:[7 2 3 3 1 5 3 6]  Fitness:21
# Chromosome:[6 4 1 4 1 0 3 5]  Fitness:22
# Chromosome:[6 2 1 4 1 4 1 4]  Fitness:17
# Chromosome:[6 5 1 2 1 0 3 6]  Fitness:18
#
# Chromosome:[3 2 1 3 1 2 4 6]  Fitness:20
# Chromosome:[1 2 3 3 1 5 3 4]  Fitness:16
# Chromosome:[6 4 1 0 1 4 1 4]  Fitness:16
# Chromosome:[2 2 1 4 1 0 3 5]  Fitness:22
# Chromosome:[5 2 0 3 1 2 7 4]  Fitness:22
# Chromosome:[3 2 4 3 2 5 3 5]  Fitness:17
# Chromosome:[6 2 1 4 1 4 1 7]  Fitness:20
# Chromosome:[6 5 1 2 1 1 3 4]  Fitness:17
#
# Chromosome:[2 2 1 6 1 0 3 5]  Fitness:22
# Chromosome:[6 4 1 0 1 4 2 4]  Fitness:18
# Chromosome:[5 2 4 3 2 1 3 5]  Fitness:18
# Chromosome:[3 4 0 3 1 2 7 4]  Fitness:21
# Chromosome:[3 2 3 3 1 5 3 4]  Fitness:15
# Chromosome:[6 4 1 0 0 4 1 4]  Fitness:20
# Chromosome:[2 2 1 4 1 0 3 6]  Fitness:21
# Chromosome:[5 6 0 3 1 2 7 5]  Fitness:22
#
# Chromosome:[2 6 0 1 1 2 7 5]  Fitness:20
# Chromosome:[5 2 1 2 1 0 3 6]  Fitness:15
# Chromosome:[6 4 1 0 2 4 2 4]  Fitness:20
# Chromosome:[5 2 4 3 2 1 3 5]  Fitness:18
# Chromosome:[3 4 5 3 1 5 3 4]  Fitness:15
# Chromosome:[3 2 7 3 1 2 7 4]  Fitness:20
# Chromosome:[5 2 4 6 2 1 3 4]  Fitness:21
# Chromosome:[3 1 0 3 1 2 7 5]  Fitness:22
#
# Chromosome:[3 4 5 3 1 5 3 4]  Fitness:15
# Chromosome:[3 2 7 3 1 2 7 4]  Fitness:20
# Chromosome:[5 4 4 3 1 5 3 4]  Fitness:15
# Chromosome:[3 2 4 3 0 1 3 5]  Fitness:20
# Chromosome:[3 2 7 5 1 2 3 4]  Fitness:18
# Chromosome:[5 2 4 6 2 1 5 4]  Fitness:21
# Chromosome:[6 4 1 0 2 4 2 3]  Fitness:22
# Chromosome:[5 2 0 3 2 1 3 4]  Fitness:21
#
# Chromosome:[3 4 4 3 1 5 3 4]  Fitness:15
# Chromosome:[3 2 4 3 1 2 7 4]  Fitness:19
# Chromosome:[5 2 1 1 2 4 2 3]  Fitness:20
# Chromosome:[5 4 4 6 2 1 5 4]  Fitness:18
# Chromosome:[5 4 4 1 0 1 3 5]  Fitness:20
# Chromosome:[6 2 4 3 1 5 3 4]  Fitness:19
# Chromosome:[6 4 0 6 2 1 3 4]  Fitness:19
# Chromosome:[5 2 7 0 2 4 2 3]  Fitness:21
#
# Chromosome:[6 4 0 3 2 1 3 4]  Fitness:18
# Chromosome:[6 2 3 3 1 5 3 4]  Fitness:18
# Chromosome:[0 4 4 1 0 1 3 5]  Fitness:21
# Chromosome:[5 4 4 6 2 6 5 4]  Fitness:17
# Chromosome:[6 4 0 6 2 1 0 4]  Fitness:17
# Chromosome:[5 2 7 0 2 4 2 6]  Fitness:21
# Chromosome:[4 4 4 3 1 5 3 4]  Fitness:15
# Chromosome:[6 2 4 2 0 1 3 5]  Fitness:23
#
# Chromosome:[6 4 0 0 5 4 2 6]  Fitness:23
# Chromosome:[5 2 7 6 2 1 0 4]  Fitness:22
# Chromosome:[6 2 3 4 1 5 3 4]  Fitness:19
# Chromosome:[0 4 4 1 0 1 3 3]  Fitness:19
# Chromosome:[5 2 7 2 2 4 2 6]  Fitness:16
# Chromosome:[4 4 4 3 4 5 3 4]  Fitness:12
# Chromosome:[4 7 4 3 1 5 3 5]  Fitness:22
# Chromosome:[6 2 4 2 0 1 3 4]  Fitness:21
#
# Chromosome:[7 2 3 4 1 5 3 3]  Fitness:18
# Chromosome:[0 4 4 1 0 3 3 4]  Fitness:20
# Chromosome:[4 2 4 3 1 5 3 4]  Fitness:19
# Chromosome:[6 2 3 2 0 1 3 5]  Fitness:22
# Chromosome:[5 2 3 4 1 5 3 5]  Fitness:17
# Chromosome:[4 2 7 6 2 1 0 4]  Fitness:22
# Chromosome:[4 4 1 3 4 5 3 4]  Fitness:17
# Chromosome:[5 2 7 2 2 4 2 1]  Fitness:17
#
# Chromosome:[0 4 4 1 1 3 3 4]  Fitness:18
# Chromosome:[3 2 4 3 1 5 3 4]  Fitness:18
# Chromosome:[4 4 1 3 3 5 3 4]  Fitness:19
# Chromosome:[4 1 7 6 2 1 0 4]  Fitness:22
# Chromosome:[6 4 1 3 4 4 2 1]  Fitness:18
# Chromosome:[5 2 7 2 3 5 3 4]  Fitness:20
# Chromosome:[4 2 7 6 2 1 0 0]  Fitness:22
# Chromosome:[5 2 3 4 1 5 4 5]  Fitness:16
#
# Chromosome:[3 2 4 1 1 5 3 4]  Fitness:21
# Chromosome:[4 4 5 3 3 5 3 4]  Fitness:17
# Chromosome:[5 2 7 6 3 1 0 0]  Fitness:23
# Chromosome:[4 2 7 2 3 5 2 4]  Fitness:23
# Chromosome:[6 4 1 1 4 5 3 4]  Fitness:22
# Chromosome:[5 2 7 2 3 0 2 1]  Fitness:19
# Chromosome:[4 1 7 6 2 2 2 1]  Fitness:22
# Chromosome:[6 4 1 3 4 4 0 2]  Fitness:19
#
# Chromosome:[5 2 7 6 2 2 2 6]  Fitness:19
# Chromosome:[4 1 7 5 3 0 2 1]  Fitness:24
# Chromosome:[4 2 7 2 3 5 2 4]  Fitness:23
# Chromosome:[5 7 7 6 3 1 0 0]  Fitness:22
# Chromosome:[5 2 4 6 3 1 0 0]  Fitness:23
# Chromosome:[4 4 5 7 3 5 3 4]  Fitness:18
# Chromosome:[5 2 7 2 3 0 4 1]  Fitness:22
# Chromosome:[6 4 1 4 4 5 3 4]  Fitness:20
#
# Chromosome:[5 2 5 7 3 2 3 4]  Fitness:19
# Chromosome:[4 4 4 2 3 1 0 0]  Fitness:18
# Chromosome:[4 1 6 5 3 0 2 1]  Fitness:20
# Chromosome:[4 5 7 2 3 5 2 4]  Fitness:23
# Chromosome:[4 2 7 6 3 1 0 0]  Fitness:24
# Chromosome:[5 7 7 2 3 5 1 4]  Fitness:22
# Chromosome:[5 7 7 6 3 1 0 1]  Fitness:21
# Chromosome:[5 2 5 6 3 1 0 0]  Fitness:21
#
# Chromosome:[4 5 7 2 3 3 2 0]  Fitness:22
# Chromosome:[4 3 7 6 3 1 0 4]  Fitness:23
# Chromosome:[4 2 0 6 3 5 1 4]  Fitness:26
# Chromosome:[5 7 7 3 3 1 0 0]  Fitness:20
# Chromosome:[5 7 5 6 5 1 0 0]  Fitness:20
# Chromosome:[5 2 7 3 3 1 0 1]  Fitness:21
# Chromosome:[5 7 7 2 3 5 1 3]  Fitness:20
# Chromosome:[5 7 7 6 3 1 5 4]  Fitness:22
#
# Chromosome:[5 7 7 3 3 1 0 0]  Fitness:20
# Chromosome:[5 7 5 7 5 1 0 0]  Fitness:21
# Chromosome:[5 7 5 6 4 1 0 1]  Fitness:20
# Chromosome:[5 2 7 3 5 1 0 0]  Fitness:20
# Chromosome:[4 1 0 3 3 1 0 0]  Fitness:17
# Chromosome:[5 7 7 1 3 5 1 4]  Fitness:23
# Chromosome:[5 2 0 6 3 5 1 4]  Fitness:26
# Chromosome:[4 3 7 6 3 1 0 4]  Fitness:23
#
# Chromosome:[5 7 5 6 4 1 0 1]  Fitness:20
# Chromosome:[5 7 5 6 5 1 0 0]  Fitness:20
# Chromosome:[4 1 0 3 3 1 0 0]  Fitness:17
# Chromosome:[5 5 7 3 5 1 0 0]  Fitness:16
# Chromosome:[5 5 7 1 3 5 1 4]  Fitness:22
# Chromosome:[5 2 0 6 3 5 1 4]  Fitness:26
# Chromosome:[5 7 6 6 4 1 0 0]  Fitness:22
# Chromosome:[5 2 7 3 5 1 0 1]  Fitness:19
#
# Chromosome:[5 2 0 6 3 5 1 5]  Fitness:23
# Chromosome:[5 7 6 6 4 1 0 0]  Fitness:22
# Chromosome:[5 7 0 3 3 2 0 0]  Fitness:20
# Chromosome:[4 1 0 6 5 1 0 0]  Fitness:21
# Chromosome:[5 5 7 6 3 5 1 4]  Fitness:22
# Chromosome:[5 1 7 3 5 1 0 0]  Fitness:19
# Chromosome:[5 2 7 3 5 1 0 1]  Fitness:19
# Chromosome:[5 7 6 6 7 1 0 0]  Fitness:22
#
# Chromosome:[5 1 0 6 5 1 0 0]  Fitness:20
# Chromosome:[4 1 0 3 0 2 0 0]  Fitness:17
# Chromosome:[5 7 6 6 7 1 0 2]  Fitness:22
# Chromosome:[5 2 0 3 5 1 0 1]  Fitness:20
# Chromosome:[5 5 7 6 3 5 1 0]  Fitness:20
# Chromosome:[5 1 7 3 5 1 2 4]  Fitness:21
# Chromosome:[4 1 0 6 5 1 1 4]  Fitness:22
# Chromosome:[5 5 7 6 3 5 6 0]  Fitness:20
